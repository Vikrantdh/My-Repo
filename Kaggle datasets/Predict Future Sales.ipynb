# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import product
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder
import gc
# %matplotlib inline

# %%
train = pd.read_csv("sales_train_v2.csv")
items = pd.read_csv("items.csv")
shops = pd.read_csv("shops.csv")
cats = pd.read_csv("item_categories.csv")
test = pd.read_csv("sales_test.csv").set_index('ID')

# %%
train.head(2)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2935847  22.10.2015              33       25     7440       299.0
# 2935848  03.10.2015              33       25     7460       299.0
#
#          item_cnt_day
# 2935847           1.0
# 2935848           1.0

# %%
items.head(7)
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
# 5  ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# 6           ***УДАР ПО ВОРОТАМ (UNI)               D        6
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40
# 5                40
# 6                40

# %%
shops.head(7)
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4
# 5          Вологда ТРЦ "Мармелад"        5
# 6      Воронеж (Плехановская, 13)        6

# %%
cats.head(7)
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4
# 5      Аксессуары - PSVita                 5
# 6    Аксессуары - XBOX 360                 6

# %%
test.head(2)
# Out:
#     shop_id  item_id
# ID
# 0         5     5037
# 1         5     5320

# %%
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops['city_code'] = LabelEncoder().fit_transform(shops['city'])
shops = shops[['shop_id','city_code']]
shops.head()
# Out:
#    shop_id  city_code
# 0        0          0
# 1        1          0
# 2        2          1
# 3        3          2
# 4        4          3

# %%
cats['type'] = cats['item_category_name'].str.split('-').map(lambda x: x[0].strip())
cats['type_code'] = LabelEncoder().fit_transform(cats['type'])
# if subtype is nan then type
cats['subtype'] = cats['item_category_name'].str.split('-').map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['subtype_code'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','type_code', 'subtype_code']]

# %%
cats.head()
# Out:
#    item_category_id  type_code  subtype_code
# 0                 0          0            29
# 1                 1          1             9
# 2                 2          1            10
# 3                 3          1            11
# 4                 4          1            13

# %%
train[train['item_price'] < 0]

# %%
median = train[(train.shop_id==32)&(train.item_id==2973)&(train.date_block_num==4)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

# %%
train['date'] = pd.to_datetime(train['date'])
train['month'] = train['date'].apply(lambda time: time.month)
train['year']  = train['date'].apply(lambda time: time.year)

# %%
train['revenue'] = train['item_price'] *  train['item_cnt_day']

# %%
test['date_block_num'] = 34
test['month'] = 11
test['year'] = 2015

# %%
total = pd.concat([train.drop('date',axis=1), test], ignore_index=True, sort=False)
total.fillna(0,inplace=True)
total.head()
# Out:
#    date_block_num  shop_id  item_id  item_price  item_cnt_day  month  year
# 0               0       59    22154      999.00           1.0      2  2013
# 1               0       25     2552      899.00           1.0      3  2013
# 2               0       25     2552      899.00          -1.0      5  2013
# 3               0       25     2554     1709.05           1.0      6  2013
# 4               0       25     2555     1099.00           1.0      1  2013

# %%
group = total.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']

total = pd.merge(total, group, on=['date_block_num','shop_id','item_id'], how='left')
total['item_cnt_month'] = total['item_cnt_month'].fillna(0)

total.head()
# Out:
#                                 item_cnt_month
# date_block_num shop_id item_id
# 0              0       32                  6.0
#                        33                  3.0
#                        35                  1.0
#                        43                  1.0
#                        51                  2.0

# %%
items.drop('item_name',axis=1,inplace=True)
total = pd.merge(total, items, on='item_id', how='left')

total = pd.merge(total, cats, on='item_category_id', how='left')

total = pd.merge(total, shops, on='shop_id', how='left')
total.head()
# Out:
#    date_block_num  shop_id  item_id  item_price  item_cnt_day  month  year  \
# 0               0       59    22154      999.00           1.0      2  2013
# 1               0       25     2552      899.00           1.0      3  2013
# 2               0       25     2552      899.00          -1.0      5  2013
# 3               0       25     2554     1709.05           1.0      6  2013
# 4               0       25     2555     1099.00           1.0      1  2013
#
#    item_cnt_month  item_category_id
# 0             1.0                37
# 1             0.0                58
# 2             0.0                58
# 3             1.0                58
# 4             1.0                56

# %%
def lag(lags, col):
    
    for i in lags:
        
        total[col+'_lag_'+str(i)] = total[col].shift(i)
        
    total.fillna(0, inplace=True)

# %%
lag([1,2,3,6,12], 'item_cnt_month')

# %%
group = total.groupby(['date_block_num']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_avg_item_cnt']

total = pd.merge(total, group, on=['date_block_num'], how='left')
total['date_avg_item_cnt'] = total['date_avg_item_cnt'].fillna(0)

lag([1,2,3,6,12], 'date_avg_item_cnt')

# %%
group = total.groupby(['date_block_num','item_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_item_avg_item_cnt']

total = pd.merge(total, group, on=['date_block_num','item_id'], how='left')
total['date_item_avg_item_cnt'] = total['date_item_avg_item_cnt'].fillna(0)

lag([1,2,3,6,12], 'date_item_avg_item_cnt')
# Out:
#                         date_item_avg_item_cnt
# date_block_num item_id
# 0              19                     1.000000
#                27                     1.000000
#                28                     2.000000
#                29                     1.000000
#                32                    16.128889

# %%
group = total.groupby(['date_block_num','shop_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_avg_item_cnt']

total = pd.merge(total, group, on=['date_block_num','shop_id'], how='left')
total['date_shop_avg_item_cnt'] = total['date_shop_avg_item_cnt'].fillna(0)

lag([1,2,3,6,12], 'date_shop_avg_item_cnt')
# Out:
#                         date_shop_avg_item_cnt
# date_block_num shop_id
# 0              0                      5.798873
#                1                      3.710839
#                2                      2.483660
#                3                      2.056075
#                4                      4.761352

# %%
group = total.groupby(['date_block_num','shop_id','item_category_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_cat_avg_item_cnt']

total = pd.merge(total, group, on=['date_block_num','shop_id','item_category_id'], how='left')
total['date_shop_cat_avg_item_cnt'] = total['date_shop_cat_avg_item_cnt'].fillna(0)

lag([1], 'date_shop_avg_item_cnt')

# %%
group = total.groupby(['date_block_num','item_category_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_cat_avg_item_cnt']

total = pd.merge(total, group, on=['date_block_num','item_category_id'], how='left')
total['date_cat_avg_item_cnt'] = total['date_cat_avg_item_cnt'].fillna(0)

lag([1], 'date_shop_avg_item_cnt')

# %%
group = total.groupby(['date_block_num','city_code','item_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_city_item_avg_item_cnt']

total = pd.merge(total, group, on=['date_block_num','city_code','item_id'], how='left')
total['date_city_item_avg_item_cnt'] = total['date_city_item_avg_item_cnt'].fillna(0)

lag([1], 'date_shop_avg_item_cnt')

# %%
total= total[total['date_block_num'] > 11 ]
total.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-b4222c99d4a9> in <module>
# ----> 1 total= total[total.date_block_num > 11 ]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'date_block_num'

# %%
X_train = total[total.date_block_num < 33].drop(['item_cnt_month'], axis=1)
y_train = total[total.date_block_num < 33]['item_cnt_month']
X_valid = total[total.date_block_num == 33].drop(['item_cnt_month'], axis=1)
y_valid = total[total.date_block_num == 33]['item_cnt_month']
X_test = total[total.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
del train
del items
del shops
del cats 
del group
del total
gc.collect()
# Out:
# 84

# %%
model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

model.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_valid, y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [0]	validation_0-rmse:28.686	validation_1-rmse:47.4049
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:26.9311	validation_1-rmse:46.4023
# [2]	validation_0-rmse:25.3974	validation_1-rmse:45.6236
# [3]	validation_0-rmse:24.0496	validation_1-rmse:44.9534
# [4]	validation_0-rmse:22.8744	validation_1-rmse:44.5102
# [5]	validation_0-rmse:21.8797	validation_1-rmse:44.029
# [6]	validation_0-rmse:21.0422	validation_1-rmse:43.6862
# [7]	validation_0-rmse:20.283	validation_1-rmse:43.3911
# [8]	validation_0-rmse:19.6442	validation_1-rmse:43.3237
# [9]	validation_0-rmse:19.1255	validation_1-rmse:43.1559
# [10]	validation_0-rmse:18.4079	validation_1-rmse:42.3925
# [11]	validation_0-rmse:18.016	validation_1-rmse:42.3419
# [12]	validation_0-rmse:17.6237	validation_1-rmse:42.4077
# [13]	validation_0-rmse:17.2305	validation_1-rmse:42.2417
# [14]	validation_0-rmse:16.9048	validation_1-rmse:42.2029
# [15]	validation_0-rmse:16.623	validation_1-rmse:42.3284
# [16]	validation_0-rmse:16.4181	validation_1-rmse:42.2125
# [17]	validation_0-rmse:16.1977	validation_1-rmse:42.1011
# [18]	validation_0-rmse:15.9847	validation_1-rmse:41.941
# [19]	validation_0-rmse:15.8211	validation_1-rmse:41.9298
# [20]	validation_0-rmse:15.6818	validation_1-rmse:41.8559
# [21]	validation_0-rmse:15.558	validation_1-rmse:41.8517
# [22]	validation_0-rmse:15.4288	validation_1-rmse:41.8139
# [23]	validation_0-rmse:15.3291	validation_1-rmse:41.7723
# [24]	validation_0-rmse:15.2183	validation_1-rmse:41.8406
# [25]	validation_0-rmse:15.1477	validation_1-rmse:41.8319
# [26]	validation_0-rmse:15.0839	validation_1-rmse:41.8733
# [27]	validation_0-rmse:15.0162	validation_1-rmse:41.8138
# [28]	validation_0-rmse:14.9496	validation_1-rmse:41.7936
# [29]	validation_0-rmse:14.8731	validation_1-rmse:41.8591
# [30]	validation_0-rmse:14.8328	validation_1-rmse:41.7576
# [31]	validation_0-rmse:14.7667	validation_1-rmse:41.8279
# [32]	validation_0-rmse:14.7226	validation_1-rmse:41.8238
# [33]	validation_0-rmse:14.678	validation_1-rmse:41.9621
# [34]	validation_0-rmse:14.5803	validation_1-rmse:41.719
# [35]	validation_0-rmse:14.5321	validation_1-rmse:41.7056
# [36]	validation_0-rmse:14.4687	validation_1-rmse:41.619
# [37]	validation_0-rmse:14.403	validation_1-rmse:41.6236
# [38]	validation_0-rmse:14.3473	validation_1-rmse:41.6672
# [39]	validation_0-rmse:14.3294	validation_1-rmse:41.6728
# [40]	validation_0-rmse:14.2551	validation_1-rmse:41.6817
# [41]	validation_0-rmse:14.21	validation_1-rmse:41.642
# [42]	validation_0-rmse:14.1724	validation_1-rmse:41.5936
# [43]	validation_0-rmse:14.1445	validation_1-rmse:41.595
# [44]	validation_0-rmse:14.1248	validation_1-rmse:41.5955
# [45]	validation_0-rmse:14.0876	validation_1-rmse:41.5788
# [46]	validation_0-rmse:14.0511	validation_1-rmse:41.5521
# [47]	validation_0-rmse:14.0258	validation_1-rmse:41.5301
# [48]	validation_0-rmse:14.0007	validation_1-rmse:41.5332
# [49]	validation_0-rmse:13.9885	validation_1-rmse:41.5463
# [50]	validation_0-rmse:13.9547	validation_1-rmse:41.4542
# [51]	validation_0-rmse:13.9256	validation_1-rmse:41.4324
# [52]	validation_0-rmse:13.8948	validation_1-rmse:41.3351
# [53]	validation_0-rmse:13.8664	validation_1-rmse:41.3277
# [54]	validation_0-rmse:13.8529	validation_1-rmse:41.3249
# [55]	validation_0-rmse:13.8062	validation_1-rmse:41.3261
# [56]	validation_0-rmse:13.7442	validation_1-rmse:41.2852
# [57]	validation_0-rmse:13.7034	validation_1-rmse:41.2779
# [58]	validation_0-rmse:13.6723	validation_1-rmse:41.3106
# [59]	validation_0-rmse:13.6308	validation_1-rmse:41.2636
# [60]	validation_0-rmse:13.5902	validation_1-rmse:41.2699
# [61]	validation_0-rmse:13.5475	validation_1-rmse:41.1822
# [62]	validation_0-rmse:13.5297	validation_1-rmse:41.1545
# [63]	validation_0-rmse:13.5137	validation_1-rmse:41.1448
# [64]	validation_0-rmse:13.4675	validation_1-rmse:41.1107
# [65]	validation_0-rmse:13.4284	validation_1-rmse:41.1095
# [66]	validation_0-rmse:13.395	validation_1-rmse:41.1004
# [67]	validation_0-rmse:13.3678	validation_1-rmse:41.0769
# [68]	validation_0-rmse:13.3545	validation_1-rmse:41.0731
# [69]	validation_0-rmse:13.3397	validation_1-rmse:41.0501
# [70]	validation_0-rmse:13.3255	validation_1-rmse:41.045
# [71]	validation_0-rmse:13.3038	validation_1-rmse:41.0539
# [72]	validation_0-rmse:13.2939	validation_1-rmse:41.0531
# [73]	validation_0-rmse:13.2824	validation_1-rmse:41.077
# [74]	validation_0-rmse:13.2596	validation_1-rmse:41.0777
# [75]	validation_0-rmse:13.2516	validation_1-rmse:41.0794
# [76]	validation_0-rmse:13.2371	validation_1-rmse:41.0697
# [77]	validation_0-rmse:13.1986	validation_1-rmse:41.0642
# [78]	validation_0-rmse:13.182	validation_1-rmse:41.0613
# [79]	validation_0-rmse:13.1538	validation_1-rmse:41.0433
# [80]	validation_0-rmse:13.138	validation_1-rmse:41.0389
# [81]	validation_0-rmse:13.107	validation_1-rmse:41.0535
# [82]	validation_0-rmse:13.0769	validation_1-rmse:41.0655
# [83]	validation_0-rmse:13.0543	validation_1-rmse:41.0554
# [84]	validation_0-rmse:13.0389	validation_1-rmse:41.0396
# [85]	validation_0-rmse:13.0227	validation_1-rmse:41.0112
# [86]	validation_0-rmse:13.0055	validation_1-rmse:41.0029
# [87]	validation_0-rmse:12.9851	validation_1-rmse:41.0024
# [88]	validation_0-rmse:12.955	validation_1-rmse:41.0057
# [89]	validation_0-rmse:12.9347	validation_1-rmse:40.9929
# [90]	validation_0-rmse:12.9192	validation_1-rmse:41.0023
# [91]	validation_0-rmse:12.9028	validation_1-rmse:40.9831
# [92]	validation_0-rmse:12.8877	validation_1-rmse:40.9957
# [93]	validation_0-rmse:12.8669	validation_1-rmse:40.973
# [94]	validation_0-rmse:12.8468	validation_1-rmse:40.9632
# [95]	validation_0-rmse:12.8377	validation_1-rmse:40.9578
# [96]	validation_0-rmse:12.8286	validation_1-rmse:40.9383
# [97]	validation_0-rmse:12.8165	validation_1-rmse:40.9473
# [98]	validation_0-rmse:12.814	validation_1-rmse:40.9472
# [99]	validation_0-rmse:12.8048	validation_1-rmse:40.9534
# [100]	validation_0-rmse:12.7966	validation_1-rmse:40.9581
# [101]	validation_0-rmse:12.7742	validation_1-rmse:40.9426
# [102]	validation_0-rmse:12.7727	validation_1-rmse:40.9435
# [103]	validation_0-rmse:12.7522	validation_1-rmse:40.9385
# [104]	validation_0-rmse:12.7288	validation_1-rmse:40.9549
# [105]	validation_0-rmse:12.7119	validation_1-rmse:40.9509
# [106]	validation_0-rmse:12.6753	validation_1-rmse:40.9675
# Stopping. Best iteration:
# [96]	validation_0-rmse:12.8286	validation_1-rmse:40.9383
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, eta=0.3, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=8,
#        min_child_weight=300, missing=None, n_estimators=1000, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=42, silent=True,
#        subsample=0.8)

# %%
y_pred = model.predict(X_valid).clip(0, 20)
y_test = model.predict(X_test).clip(0, 20)

# %%
submission = pd.DataFrame({"ID":test.index, "item_cnt_month":y_test})
submission.to_csv('submission.csv',index=False)
